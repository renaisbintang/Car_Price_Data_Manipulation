# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/renaisbintang/Car_Price_Data_Preprocessing/main/data_science_project1.csv')
df.head()
# Out:
#   make_model body_type body_type.1     km Gearing Type  price
# 0    Audi A1    Sedans      Sedans  56013    Automatic  15770
# 1    Audi A1    Sedans      Sedans  80000    Automatic  14500
# 2    Audi A1    Sedans      Sedans  83450    Automatic  14640
# 3    Audi A1    Sedans      Sedans  73000    Automatic  14500
# 4    Audi A1    Sedans      Sedans  16200    Automatic  16790

# %%
df.shape
# Out:
# (4800, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4800 entries, 0 to 4799
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   make_model    4800 non-null   object
#  1   body_type     4800 non-null   object
#  2   body_type.1   4800 non-null   object
#  3   km            4800 non-null   int64
#  4   Gearing Type  4800 non-null   object
#  5   price         4800 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 225.1+ KB

# %%
df.describe()
# Out:
#                   km         price
# count    4800.000000   4800.000000
# mean    31912.910417  19722.871875
# std     35899.452772   4337.519969
# min         0.000000   5555.000000
# 25%      4700.000000  15990.000000
# 50%     20005.000000  19588.000000
# 75%     47800.000000  22692.500000
# max    291800.000000  56100.000000

# %%
df.isna().sum()
# Out:
# make_model      0
# body_type       0
# body_type.1     0
# km              0
# Gearing Type    0
# price           0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# make_model      0
# body_type       0
# body_type.1     0
# km              0
# Gearing Type    0
# price           0
# dtype: int64

# %%
df.nunique()
# Out:
# make_model         3
# body_type          7
# body_type.1        7
# km              2443
# Gearing Type       3
# price           1155
# dtype: int64

# %%
df = df.drop(columns=['body_type.1'])

# %%
df
# Out:
#      make_model      body_type     km Gearing Type  price
# 0       Audi A1         Sedans  56013    Automatic  15770
# 1       Audi A1         Sedans  80000    Automatic  14500
# 2       Audi A1         Sedans  83450    Automatic  14640
# 3       Audi A1         Sedans  73000    Automatic  14500
# 4       Audi A1         Sedans  16200    Automatic  16790
# ...         ...            ...    ...          ...    ...
# 4795    Audi A3         Sedans     54       Manual  25000
# 4796    Audi A3         Sedans     50       Manual  24980
# 4797    Audi A3  Station wagon   6666       Manual  24980
# 4798    Audi A3         Sedans     10       Manual  24980
# 4799    Audi A3         Sedans     10       Manual  24980
#
# [4800 rows x 5 columns]

# %%
df.sort_values(by=['price'], ascending=False)
# Out:
#      make_model      body_type      km    Gearing Type  price
# 3002    Audi A3    Convertible    8364  Semi-automatic  56100
# 3003    Audi A3        Compact     750  Semi-automatic  41495
# 3001    Audi A3        Compact       7  Semi-automatic  39575
# 3005    Audi A3        Compact       7  Semi-automatic  38725
# 3004    Audi A3        Compact       7  Semi-automatic  38495
# ...         ...            ...     ...             ...    ...
# 60      Audi A1        Compact  130000          Manual  10490
# 58      Audi A1         Sedans   85000          Manual  10300
# 59      Audi A1         Sedans  192000          Manual  10000
# 24      Audi A1         Sedans  115000          Manual   8999
# 2670    Audi A3  Station wagon    5558          Manual   5555
#
# [4800 rows x 5 columns]

# %%
df.sort_values(by=['price'], ascending=True)
# Out:
#      make_model      body_type      km    Gearing Type  price
# 2670    Audi A3  Station wagon    5558          Manual   5555
# 24      Audi A1         Sedans  115000          Manual   8999
# 59      Audi A1         Sedans  192000          Manual  10000
# 58      Audi A1         Sedans   85000          Manual  10300
# 60      Audi A1        Compact  130000          Manual  10490
# ...         ...            ...     ...             ...    ...
# 3004    Audi A3        Compact       7  Semi-automatic  38495
# 3005    Audi A3        Compact       7  Semi-automatic  38725
# 3001    Audi A3        Compact       7  Semi-automatic  39575
# 3003    Audi A3        Compact     750  Semi-automatic  41495
# 3002    Audi A3    Convertible    8364  Semi-automatic  56100
#
# [4800 rows x 5 columns]

# %%
df.sort_values(by=['km'], ascending=False)
# Out:
#      make_model      body_type      km Gearing Type  price
# 2478    Audi A3         Sedans  291800       Manual  14980
# 2664    Audi A3  Station wagon  209000       Manual  11790
# 2462    Audi A3         Sedans  207000    Automatic  12850
# 2665    Audi A3  Station wagon  204000       Manual  11790
# 2526    Audi A3        Compact  200814       Manual  15445
# ...         ...            ...     ...          ...    ...
# 2082    Audi A1         Sedans       0       Manual  22550
# 2131    Audi A1        Compact       0       Manual  21890
# 4308    Audi A3  Station wagon       0    Automatic  26990
# 4307    Audi A3         Sedans       0    Automatic  26995
# 1851    Audi A1         Sedans       0       Manual  21700
#
# [4800 rows x 5 columns]

# %%
df.nlargest(5, 'km')
# Out:
#      make_model      body_type      km Gearing Type  price
# 2478    Audi A3         Sedans  291800       Manual  14980
# 2664    Audi A3  Station wagon  209000       Manual  11790
# 2462    Audi A3         Sedans  207000    Automatic  12850
# 2665    Audi A3  Station wagon  204000       Manual  11790
# 2526    Audi A3        Compact  200814       Manual  15445

# %%
df.nsmallest(5, 'km')
# Out:
#     make_model body_type  km    Gearing Type  price
# 645    Audi A1    Sedans   0  Semi-automatic  30000
# 653    Audi A1    Sedans   0  Semi-automatic  25900
# 764    Audi A1    Sedans   0       Automatic  21300
# 852    Audi A1   Compact   0       Automatic  21200
# 919    Audi A1   Compact   0       Automatic  20380

# %%
df.loc[(df['Gearing Type'] == 'Automatic'), ['make_model']]
# Out:
#      make_model
# 0       Audi A1
# 1       Audi A1
# 2       Audi A1
# 3       Audi A1
# 4       Audi A1
# ...         ...
# 4499    Audi A3
# 4500    Audi A3
# 4501    Audi A3
# 4502    Audi A3
# 4503    Audi A3
#
# [2092 rows x 1 columns]

# %%
df.loc[(df['Gearing Type'] == 'Automatic'), ['make_model', 'body_type']]
# Out:
#      make_model      body_type
# 0       Audi A1         Sedans
# 1       Audi A1         Sedans
# 2       Audi A1         Sedans
# 3       Audi A1         Sedans
# 4       Audi A1         Sedans
# ...         ...            ...
# 4499    Audi A3         Sedans
# 4500    Audi A3         Sedans
# 4501    Audi A3  Station wagon
# 4502    Audi A3         Sedans
# 4503    Audi A3         Sedans
#
# [2092 rows x 2 columns]

# %%
df.loc[(df['Gearing Type'] == 'Automatic') & (df['body_type']), ['make_model', 'body_type']]
# Out:
#      make_model      body_type
# 0       Audi A1         Sedans
# 1       Audi A1         Sedans
# 2       Audi A1         Sedans
# 3       Audi A1         Sedans
# 4       Audi A1         Sedans
# ...         ...            ...
# 4499    Audi A3         Sedans
# 4500    Audi A3         Sedans
# 4501    Audi A3  Station wagon
# 4502    Audi A3         Sedans
# 4503    Audi A3         Sedans
#
# [2092 rows x 2 columns]

# %%
df.iloc[:, [1,3]]
# Out:
#           body_type Gearing Type
# 0            Sedans    Automatic
# 1            Sedans    Automatic
# 2            Sedans    Automatic
# 3            Sedans    Automatic
# 4            Sedans    Automatic
# ...             ...          ...
# 4795         Sedans       Manual
# 4796         Sedans       Manual
# 4797  Station wagon       Manual
# 4798         Sedans       Manual
# 4799         Sedans       Manual
#
# [4800 rows x 2 columns]

# %%
df.iloc[:, 1:3]
# Out:
#           body_type     km
# 0            Sedans  56013
# 1            Sedans  80000
# 2            Sedans  83450
# 3            Sedans  73000
# 4            Sedans  16200
# ...             ...    ...
# 4795         Sedans     54
# 4796         Sedans     50
# 4797  Station wagon   6666
# 4798         Sedans     10
# 4799         Sedans     10
#
# [4800 rows x 2 columns]

# %%
df.iloc[5:10, 1:4]
# Out:
#        body_type     km Gearing Type
# 5         Sedans  63668    Automatic
# 6  Station wagon  62111    Automatic
# 7        Compact  14986    Automatic
# 8         Sedans  57000    Automatic
# 9         Sedans  16103    Automatic

# %%
df['price_per_km'] = df['price']/df['km']
df
# Out:
#      make_model      body_type     km Gearing Type  price  price_per_km
# 0       Audi A1         Sedans  56013    Automatic  15770      0.281542
# 1       Audi A1         Sedans  80000    Automatic  14500      0.181250
# 2       Audi A1         Sedans  83450    Automatic  14640      0.175434
# 3       Audi A1         Sedans  73000    Automatic  14500      0.198630
# 4       Audi A1         Sedans  16200    Automatic  16790      1.036420
# ...         ...            ...    ...          ...    ...           ...
# 4795    Audi A3         Sedans     54       Manual  25000    462.962963
# 4796    Audi A3         Sedans     50       Manual  24980    499.600000
# 4797    Audi A3  Station wagon   6666       Manual  24980      3.747375
# 4798    Audi A3         Sedans     10       Manual  24980   2498.000000
# 4799    Audi A3         Sedans     10       Manual  24980   2498.000000
#
# [4800 rows x 6 columns]

# %%
df.groupby('body_type')['price'].mean()
# Out:
# body_type
# Compact          18821.907023
# Convertible      27184.714286
# Coupe            16768.000000
# Off-Road         28200.000000
# Other            20764.285714
# Sedans           19931.802289
# Station wagon    20156.942308
# Name: price, dtype: float64

# %%
df.groupby(['make_model', 'body_type'])['price'].mean()
# Out:
# make_model  body_type
# Audi A1     Compact          18868.000000
#             Coupe            14925.000000
#             Other            21904.166667
#             Sedans           18345.354965
#             Station wagon    17614.555556
# Audi A2     Off-Road         28200.000000
# Audi A3     Compact          18585.575758
#             Convertible      27184.714286
#             Coupe            17996.666667
#             Other            19244.444444
#             Sedans           20847.445848
#             Station wagon    20346.045455
# Name: price, dtype: float64

# %%
df.groupby(['make_model', 'body_type'])['price'].sum()
# Out:
# make_model  body_type
# Audi A1     Compact          15962328
#             Coupe               29850
#             Other              262850
#             Sedans           23463709
#             Station wagon      317062
# Audi A2     Off-Road            28200
# Audi A3     Compact           3066620
#             Convertible        190293
#             Coupe               53990
#             Other              173200
#             Sedans           46197940
#             Station wagon     4923743
# Name: price, dtype: int64

# %%
df.groupby('make_model').agg(average_km=('km', 'mean'), sum_km=('km', 'sum'))
# Out:
#               average_km     sum_km
# make_model
# Audi A1     23484.994900   50657134
# Audi A2     26166.000000      26166
# Audi A3     38795.862983  102498670

# %%
pd.crosstab(df['make_model'], df['body_type'])
# Out:
# body_type   Compact  Convertible  Coupe  Off-Road  Other  Sedans  \
# make_model
# Audi A1         846            0      2         0     12    1279
# Audi A2           0            0      0         1      0       0
# Audi A3         165            7      3         0      9    2216
#
# body_type   Station wagon
# make_model
# Audi A1                18
# Audi A2                 0
# Audi A3               242

# %%
df.pivot_table(index='make_model', columns='Gearing Type', values='price', aggfunc='mean')
# Out:
# Gearing Type     Automatic        Manual  Semi-automatic
# make_model
# Audi A1       21123.773707  16468.409669    20333.640000
# Audi A2                NaN  28200.000000             NaN
# Audi A3       21417.317010  19315.503586    24372.520179

# %%
df.pivot_table(index=['make_model', 'body_type'], columns='Gearing Type', values='price', aggfunc='mean')
# Out:
# Gearing Type                 Automatic        Manual  Semi-automatic
# make_model body_type
# Audi A1    Compact        21400.833333  16934.609603    17945.000000
#            Coupe                   NaN  14925.000000             NaN
#            Other          26233.333333  20461.111111             NaN
#            Sedans         20916.711957  16104.641593    20382.387755
#            Station wagon  20776.000000  15602.727273             NaN
# Audi A2    Off-Road                NaN  28200.000000             NaN
# Audi A3    Compact        19052.323077  16049.897727    34652.333333
#            Convertible    17931.000000           NaN    34125.000000
#            Coupe          17996.666667           NaN             NaN
#            Other          20875.000000  17940.000000             NaN
#            Sedans         21577.380808  19581.539745    23588.135266
#            Station wagon  21600.666667  19477.461538             NaN

# %%
df.pivot_table(index=['make_model', 'body_type'], columns='Gearing Type', values='price', aggfunc='mean').sort_values(by=['Automatic'])
# Out:
# Gearing Type                 Automatic        Manual  Semi-automatic
# make_model body_type
# Audi A3    Convertible    17931.000000           NaN    34125.000000
#            Coupe          17996.666667           NaN             NaN
#            Compact        19052.323077  16049.897727    34652.333333
# Audi A1    Station wagon  20776.000000  15602.727273             NaN
# Audi A3    Other          20875.000000  17940.000000             NaN
# Audi A1    Sedans         20916.711957  16104.641593    20382.387755
#            Compact        21400.833333  16934.609603    17945.000000
# Audi A3    Sedans         21577.380808  19581.539745    23588.135266
#            Station wagon  21600.666667  19477.461538             NaN
# Audi A1    Other          26233.333333  20461.111111             NaN
#            Coupe                   NaN  14925.000000             NaN
# Audi A2    Off-Road                NaN  28200.000000             NaN

# %%
df.pivot_table(index=["make_model", "body_type"], columns='Gearing Type', values='price', aggfunc='mean').sort_values(by=['make_model','Automatic'], ascending=[True, False])
# Out:
# Gearing Type                 Automatic        Manual  Semi-automatic
# make_model body_type
# Audi A1    Other          26233.333333  20461.111111             NaN
#            Compact        21400.833333  16934.609603    17945.000000
#            Sedans         20916.711957  16104.641593    20382.387755
#            Station wagon  20776.000000  15602.727273             NaN
#            Coupe                   NaN  14925.000000             NaN
# Audi A2    Off-Road                NaN  28200.000000             NaN
# Audi A3    Station wagon  21600.666667  19477.461538             NaN
#            Sedans         21577.380808  19581.539745    23588.135266
#            Other          20875.000000  17940.000000             NaN
#            Compact        19052.323077  16049.897727    34652.333333
#            Coupe          17996.666667           NaN             NaN
#            Convertible    17931.000000           NaN    34125.000000

# %%
df.melt(id_vars=['make_model', 'body_type', 'Gearing Type'], var_name='value_type', value_name='value')
# Out:
#       make_model      body_type Gearing Type    value_type         value
# 0        Audi A1         Sedans    Automatic            km  56013.000000
# 1        Audi A1         Sedans    Automatic            km  80000.000000
# 2        Audi A1         Sedans    Automatic            km  83450.000000
# 3        Audi A1         Sedans    Automatic            km  73000.000000
# 4        Audi A1         Sedans    Automatic            km  16200.000000
# ...          ...            ...          ...           ...           ...
# 14395    Audi A3         Sedans       Manual  price_per_km    462.962963
# 14396    Audi A3         Sedans       Manual  price_per_km    499.600000
# 14397    Audi A3  Station wagon       Manual  price_per_km      3.747375
# 14398    Audi A3         Sedans       Manual  price_per_km   2498.000000
# 14399    Audi A3         Sedans       Manual  price_per_km   2498.000000
#
# [14400 rows x 5 columns]

# %%
df.melt(id_vars=['make_model', 'body_type', 'Gearing Type'], var_name='nama_kolom', value_name='isi_value')
# Out:
#       make_model      body_type Gearing Type    nama_kolom     isi_value
# 0        Audi A1         Sedans    Automatic            km  56013.000000
# 1        Audi A1         Sedans    Automatic            km  80000.000000
# 2        Audi A1         Sedans    Automatic            km  83450.000000
# 3        Audi A1         Sedans    Automatic            km  73000.000000
# 4        Audi A1         Sedans    Automatic            km  16200.000000
# ...          ...            ...          ...           ...           ...
# 14395    Audi A3         Sedans       Manual  price_per_km    462.962963
# 14396    Audi A3         Sedans       Manual  price_per_km    499.600000
# 14397    Audi A3  Station wagon       Manual  price_per_km      3.747375
# 14398    Audi A3         Sedans       Manual  price_per_km   2498.000000
# 14399    Audi A3         Sedans       Manual  price_per_km   2498.000000
#
# [14400 rows x 5 columns]

# %%
bin_labels_4=['Bronze', 'Silver', 'Gold', 'Platinum']
results, bin_edges = pd.qcut(df['price'], q=[0, .25, .5, .75,1], labels=bin_labels_4, retbins=True)

# %%
results
# Out:
# 0         Bronze
# 1         Bronze
# 2         Bronze
# 3         Bronze
# 4         Silver
#           ...
# 4795    Platinum
# 4796    Platinum
# 4797    Platinum
# 4798    Platinum
# 4799    Platinum
# Name: price, Length: 4800, dtype: category
# Categories (4, object): ['Bronze' < 'Silver' < 'Gold' < 'Platinum']

# %%
bin_edges
# Out:
# array([ 5555. , 15990. , 19588. , 22692.5, 56100. ])

# %%
bin_labels_4=['Bronze', 'Silver', 'Gold', 'Platinum']
results, bin_edges = pd.qcut(df['price'], q=[0, .25, .5, .75,1], labels=bin_labels_4, retbins=False)

# %%
results_table = pd.DataFrame(zip(bin_edges, bin_labels_4), columns=['Treshold', 'Tier'])

# %%
results_table
# Out:
#    Treshold      Tier
# 0    5555.0    Bronze
# 1   15990.0    Silver
# 2   19588.0      Gold
# 3   22692.5  Platinum

# %%
df['results'] = results
df
# Out:
#      make_model      body_type     km Gearing Type  price  price_per_km  \
# 0       Audi A1         Sedans  56013    Automatic  15770      0.281542
# 1       Audi A1         Sedans  80000    Automatic  14500      0.181250
# 2       Audi A1         Sedans  83450    Automatic  14640      0.175434
# 3       Audi A1         Sedans  73000    Automatic  14500      0.198630
# 4       Audi A1         Sedans  16200    Automatic  16790      1.036420
# ...         ...            ...    ...          ...    ...           ...
# 4795    Audi A3         Sedans     54       Manual  25000    462.962963
# 4796    Audi A3         Sedans     50       Manual  24980    499.600000
# 4797    Audi A3  Station wagon   6666       Manual  24980      3.747375
# 4798    Audi A3         Sedans     10       Manual  24980   2498.000000
# 4799    Audi A3         Sedans     10       Manual  24980   2498.000000
#
#        results
# 0       Bronze
# 1       Bronze
# 2       Bronze
# 3       Bronze
# 4       Silver
# ...

# %%
df['results'].value_counts()
# Out:
# Bronze      1211
# Platinum    1200
# Gold        1198
# Silver      1191
# Name: results, dtype: int64

# %%
bins = [0, 1000, 5000, 10000, 25000, 50000, 100000]
labels = [1,2,3,4,5,6]
df['binned_km'] = pd.cut(df['km'], bins = bins, labels = labels)

# %%
df
# Out:
#      make_model      body_type     km Gearing Type  price  price_per_km  \
# 0       Audi A1         Sedans  56013    Automatic  15770      0.281542
# 1       Audi A1         Sedans  80000    Automatic  14500      0.181250
# 2       Audi A1         Sedans  83450    Automatic  14640      0.175434
# 3       Audi A1         Sedans  73000    Automatic  14500      0.198630
# 4       Audi A1         Sedans  16200    Automatic  16790      1.036420
# ...         ...            ...    ...          ...    ...           ...
# 4795    Audi A3         Sedans     54       Manual  25000    462.962963
# 4796    Audi A3         Sedans     50       Manual  24980    499.600000
# 4797    Audi A3  Station wagon   6666       Manual  24980      3.747375
# 4798    Audi A3         Sedans     10       Manual  24980   2498.000000
# 4799    Audi A3         Sedans     10       Manual  24980   2498.000000
#
#        results binned_km
# 0       Bronze         6
# 1       Bronze         6
# ...

# %%
df['binned_km'].value_counts()
# Out:
# 4    1088
# 5     933
# 6     802
# 1     769
# 3     407
# 2     258
# Name: binned_km, dtype: int64

# %%
df['rank_calc'] = df['price'].rank(ascending=False)
df.sort_values(by=['rank_calc'])
# Out:
#      make_model      body_type      km    Gearing Type  price  price_per_km  \
# 3002    Audi A3    Convertible    8364  Semi-automatic  56100      6.707317
# 3003    Audi A3        Compact     750  Semi-automatic  41495     55.326667
# 3001    Audi A3        Compact       7  Semi-automatic  39575   5653.571429
# 3005    Audi A3        Compact       7  Semi-automatic  38725   5532.142857
# 3004    Audi A3        Compact       7  Semi-automatic  38495   5499.285714
# ...         ...            ...     ...             ...    ...           ...
# 60      Audi A1        Compact  130000          Manual  10490      0.080692
# 58      Audi A1         Sedans   85000          Manual  10300      0.121176
# 59      Audi A1         Sedans  192000          Manual  10000      0.052083
# 24      Audi A1         Sedans  115000          Manual   8999      0.078252
# 2670    Audi A3  Station wagon    5558          Manual   5555      0.999460
#
#        results binned_km  rank_calc
# ...

# %%
df['rank_calc'] = df['price'].rank(ascending=True)
df.sort_values(by=['rank_calc'])
# Out:
#      make_model      body_type      km    Gearing Type  price  price_per_km  \
# 2670    Audi A3  Station wagon    5558          Manual   5555      0.999460
# 24      Audi A1         Sedans  115000          Manual   8999      0.078252
# 59      Audi A1         Sedans  192000          Manual  10000      0.052083
# 58      Audi A1         Sedans   85000          Manual  10300      0.121176
# 60      Audi A1        Compact  130000          Manual  10490      0.080692
# ...         ...            ...     ...             ...    ...           ...
# 3004    Audi A3        Compact       7  Semi-automatic  38495   5499.285714
# 3005    Audi A3        Compact       7  Semi-automatic  38725   5532.142857
# 3001    Audi A3        Compact       7  Semi-automatic  39575   5653.571429
# 3003    Audi A3        Compact     750  Semi-automatic  41495     55.326667
# 3002    Audi A3    Convertible    8364  Semi-automatic  56100      6.707317
#
#        results binned_km  rank_calc
# ...

# %%
body = ['Convertible', 'Compact']
df[df.body_type.isin(body)]
# Out:
#      make_model body_type     km Gearing Type  price  price_per_km   results  \
# 7       Audi A1   Compact  14986    Automatic  14480      0.966235    Bronze
# 17      Audi A1   Compact  50280    Automatic  18400      0.365951    Silver
# 25      Audi A1   Compact  84029       Manual  11444      0.136191    Bronze
# 27      Audi A1   Compact  22000       Manual  11290      0.513182    Bronze
# 28      Audi A1   Compact  38400       Manual  11290      0.294010    Bronze
# ...         ...       ...    ...          ...    ...           ...       ...
# 4165    Audi A3   Compact   6746       Manual  20900      3.098132      Gold
# 4537    Audi A3   Compact      7       Manual  24490   3498.571429  Platinum
# 4565    Audi A3   Compact   6000       Manual  24900      4.150000  Platinum
# 4658    Audi A3   Compact   5586       Manual  22300      3.992123      Gold
# 4738    Audi A3   Compact     10       Manual  23300   2330.000000  Platinum
#
#      binned_km  rank_calc
# ...
